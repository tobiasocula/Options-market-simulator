# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
table = np.load(Path.cwd().parent / "run_cross_excitation_result" / "overviews.npy", allow_pickle=True)
table # has shape (M, N, 2, T), each entry is a dict

print(table[0, 0, 0, 1])
# Out:
# {'best_bid': None, 'best_ask': np.float64(194.9504496018676), 'spread': 0.0, 'ltp': np.float64(201.85807678914526), 'volume': 0.0, 'moneyness': np.float64(-0.047143400202973286), 'iv': None}
